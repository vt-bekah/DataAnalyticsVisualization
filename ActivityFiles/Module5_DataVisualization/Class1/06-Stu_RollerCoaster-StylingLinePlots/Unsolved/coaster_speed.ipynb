# %%
# %matplotlib inline

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create the X and Y axis lists
time = np.arange(0,130,10)
danger_drop_speeds = [9, 8, 90, 85, 80, 70, 70, 65, 55, 60, 70, 65, 50]
railgun_speeds = [75, 70, 60, 65, 60, 45, 55, 50, 40, 40, 35, 35, 30]

# %%
# Plot the charts and apply some styling
#class solution did define these as handles and referenced them in the legend line
plt.plot(time, danger_drop_speeds, linewidth=2, color='red', label="Dangerous")
plt.plot(time, railgun_speeds, linewidth=2, color='blue', label="Railgun")

# Add labels to X and Y axes :: Add title
plt.title("Coaster Speed Over Time")
plt.xlabel("Coaster Runtime")
plt.ylabel("Speed (MPH)")

# Set the limits for the X and Y axes
plt.xlim(0, 120)
plt.ylim(5, 95)

# Create a legend for the chart
plt.legend()

# Add in a grid for the chart
plt.grid()

plt.show()

# %%
# Add labels to X and Y axes :: Add title

# %%
# Set the limits for the X and Y axes

# %%
# Create a legend for the chart

# %%
# Add in a grid for the chart
